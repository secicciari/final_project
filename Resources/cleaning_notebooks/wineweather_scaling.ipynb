# %%
import pandas as pd

# %%
weatherdata = '/content/winery_weather.csv'
reviewdata = '/content/wine_reviews_cleaned.csv'
weather_df = pd.read_csv(weatherdata)
reviews = pd.read_csv(reviewdata, index_col=0)
review_df = reviews.reset_index()
rev_df = review_df.drop(columns='index')

# %%
weather_df.head()
# Out:
#                     winery_search  ...  Average Daily Precipitation (mm)
# 0            St. Julian winery US  ...                            0.0725
# 1          Sweet Cheeks winery US  ...                            0.0575
# 2    Kirkland Signature winery US  ...                            0.2350
# 3      Louis M. Martini winery US  ...                            0.0775
# 4  Richard Böcking winery Germany  ...                            0.1350
#
# [5 rows x 5 columns]

# %%
len(weather_df)
# Out:
# 7892

# %%
rev_df.head()
# Out:
#   country  points  ...              winery                 winery_search
# 0      US      87  ...          St. Julian          St. Julian winery US
# 1      US      87  ...        Sweet Cheeks        Sweet Cheeks winery US
# 2      US      87  ...  Kirkland Signature  Kirkland Signature winery US
# 3      US      87  ...    Louis M. Martini    Louis M. Martini winery US
# 4      US      87  ...            Mirassou            Mirassou winery US
#
# [5 rows x 5 columns]

# %%
len(rev_df)
# Out:
# 55461

# %%
df1 = pd.read_csv(weatherdata)
df2 = pd.read_csv(reviewdata, index_col=0)

df1.set_index('winery_search', inplace=True)
df2.set_index('winery', inplace=True)

output = df2.join(df1, on='winery_search')
output.head()
# Out:
#                    country  ...  Average Daily Precipitation (mm)
# winery                      ...
# St. Julian              US  ...                            0.0725
# Sweet Cheeks            US  ...                            0.0575
# Kirkland Signature      US  ...                            0.2350
# Louis M. Martini        US  ...                            0.0775
# Mirassou                US  ...                               NaN
#
# [5 rows x 8 columns]

# %%
output.head(20)
# Out:
#                      country  ...  Average Daily Precipitation (mm)
# winery                        ...
# St. Julian                US  ...                            0.0725
# Sweet Cheeks              US  ...                            0.0575
# Kirkland Signature        US  ...                            0.2350
# Louis M. Martini          US  ...                            0.0775
# Mirassou                  US  ...                               NaN
# Richard Böcking      Germany  ...                            0.1350
# Acrobat                   US  ...                               NaN
# Bianchi                   US  ...                            0.0250
# Castello di Amorosa       US  ...                            0.0775
# Envolve                   US  ...                            0.1250
# Erath                     US  ...                            0.1400
# Feudi del Pisciotto    Italy  ...                            0.0550
# ...

# %%
weather_df.head(20)
# Out:
#                        winery_search  ...  Average Daily Precipitation (mm)
# 0               St. Julian winery US  ...                            0.0725
# 1             Sweet Cheeks winery US  ...                            0.0575
# 2       Kirkland Signature winery US  ...                            0.2350
# 3         Louis M. Martini winery US  ...                            0.0775
# 4     Richard Böcking winery Germany  ...                            0.1350
# 5                  Bianchi winery US  ...                            0.0250
# 6      Castello di Amorosa winery US  ...                            0.0775
# 7                  Envolve winery US  ...                            0.1250
# 8                    Erath winery US  ...                            0.1400
# 9   Feudi del Pisciotto winery Italy  ...                            0.0550
# 10         Hawkins Cellars winery US  ...                            0.1350
# ...

# %%
cleanout = output.dropna()
cleanout.head(20)
# Out:
#                      country  ...  Average Daily Precipitation (mm)
# winery                        ...
# St. Julian                US  ...                            0.0725
# Sweet Cheeks              US  ...                            0.0575
# Kirkland Signature        US  ...                            0.2350
# Louis M. Martini          US  ...                            0.0775
# Richard Böcking      Germany  ...                            0.1350
# Bianchi                   US  ...                            0.0250
# Castello di Amorosa       US  ...                            0.0775
# Envolve                   US  ...                            0.1250
# Erath                     US  ...                            0.1400
# Feudi del Pisciotto    Italy  ...                            0.0550
# Hawkins Cellars           US  ...                            0.1350
# Robert Hall               US  ...                            0.0250
# ...

# %%
len(cleanout)
# Out:
# 52906

# %%
fresh_wineweather = cleanout.reset_index()
fresh_wineweather.head()
# Out:
#                winery  ... Average Daily Precipitation (mm)
# 0          St. Julian  ...                           0.0725
# 1        Sweet Cheeks  ...                           0.0575
# 2  Kirkland Signature  ...                           0.2350
# 3    Louis M. Martini  ...                           0.0775
# 4     Richard Böcking  ...                           0.1350
#
# [5 rows x 9 columns]

# %%
fresh_wineweather.to_csv('weather_scaled.csv')
