# %%
import pandas as pd
import numpy as np
import os

# %%
file = 'US_AL_pull17t20.csv'
al_df = pd.read_csv(file)

# %%
al_df.head()
# Out:
#        STATION                NAME      DATE  precipitation_in  min_soiltemp  \
# 0  USC00010583  BAY MINETTE, AL US  1/1/2017               3.1           NaN
# 1  USC00010583  BAY MINETTE, AL US  1/2/2017               5.5           NaN
# 2  USC00010583  BAY MINETTE, AL US  1/3/2017               1.6           NaN
# 3  USC00010583  BAY MINETTE, AL US  1/4/2017               0.0           NaN
# 4  USC00010583  BAY MINETTE, AL US  1/5/2017               0.0           NaN
#
#    snow_in  max_soiltemp  temp_avgF  temp_maxF  temp_minF
# 0      NaN           NaN        NaN       66.0       47.0
# 1      NaN           NaN        NaN       74.0       64.0
# 2      NaN           NaN        NaN       74.0       55.0
# 3      NaN           NaN        NaN       71.0       54.0
# 4      NaN           NaN        NaN       60.0       39.0

# %%
al_df.count()
# Out:
# STATION             126388
# NAME                126388
# DATE                126388
# precipitation_in    117991
# min_soiltemp          6439
# snow_in              35086
# max_soiltemp          6439
# temp_avgF            12598
# temp_maxF            72773
# temp_minF            72638
# dtype: int64

# %%
al_df['NAME'].unique()
# Out:
# array(['BAY MINETTE, AL US', 'GADSDEN 19 N, AL US', 'DADEVILLE 2, AL US',
#        'DEMOPOLIS LOCK AND DAM, AL US', 'FAYETTE, AL US',
#        'ADDISON, AL US', 'BEVILL LOCK AND DAM, AL US',
#        'GUNTERSVILLE, AL US', 'MARION JUNCTION 2 NE, AL US',
#        'MOULTON 2, AL US', 'EVERGREEN MIDDLETON FIELD, AL US',
#        'MOODY 2.0 ESE, AL US', 'OAKMULGEE ALABAMA, AL US',
#        'BANKHEAD ALABAMA, AL US', 'COURTLAND 2 WSW, AL US',
#        'ALICEVILLE, AL US', 'CAMDEN 1.0 NNE, AL US',
#        'CULLMAN 3 ENE, AL US', 'FORT PAYNE, AL US', 'GUIN 1.1 NW, AL US',
#        'GREENVILLE MAC CRENSHAW MEMORIAL AIRPORT, AL US',
#        'MILLBROOK 4.0 NNW, AL US', 'MADISON 1.4 NNE, AL US',
#        'HAMPTON COVE 2.1 WNW, AL US', 'DAPHNE 4.9 SE, AL US',
#        'FAIRFIELD 1.8 NE, AL US', 'MUSCLE SHOALS AIRPORT, AL US',
#        'MONTGOMERY AIRPORT, AL US', 'MOBILE REGIONAL AIRPORT, AL US',
#        'LESTER 10.5 S, AL US', 'COFFEEVILLE LOCK AND DAM, AL US',
# ...

# %%
napafile = 'Cali_Napa_testpull_13t17.csv'
napa_df = pd.read_csv(napafile)

# %%
napa_df.head()
# Out:
#        STATION               NAME        DATE  AWND AWND_ATTRIBUTES  DAPR  \
# 0  US1CANP0014  NAPA 2.2 N, CA US  2018-11-21   NaN             NaN   NaN
# 1  US1CANP0014  NAPA 2.2 N, CA US  2018-11-22   NaN             NaN   NaN
# 2  US1CANP0014  NAPA 2.2 N, CA US  2018-11-23   NaN             NaN   NaN
# 3  US1CANP0014  NAPA 2.2 N, CA US  2018-11-24   NaN             NaN   NaN
# 4  US1CANP0014  NAPA 2.2 N, CA US  2018-11-25   NaN             NaN   NaN
#
#   DAPR_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PGTM  ... WT08  WT08_ATTRIBUTES WT13  \
# 0             NaN   NaN             NaN   NaN  ...  NaN              NaN  NaN
# 1             NaN   NaN             NaN   NaN  ...  NaN              NaN  NaN
# 2             NaN   NaN             NaN   NaN  ...  NaN              NaN  NaN
# 3             NaN   NaN             NaN   NaN  ...  NaN              NaN  NaN
# 4             NaN   NaN             NaN   NaN  ...  NaN              NaN  NaN
#
# ...

# %%
sonomafile = 'Cali_Sonoma_test13t17.csv'
sono_df = pd.read_csv(sonomafile)

# %%
sono_df.head()
# Out:
#        STATION  LATITUDE  LONGITUDE  ELEVATION        DATE  DAPR  \
# 0  USC00048351   38.2994  -122.4622       29.6  2013-08-01   NaN
# 1  USC00048351   38.2994  -122.4622       29.6  2013-08-02   NaN
# 2  USC00048351   38.2994  -122.4622       29.6  2013-08-03   NaN
# 3  USC00048351   38.2994  -122.4622       29.6  2013-08-04   NaN
# 4  USC00048351   38.2994  -122.4622       29.6  2013-08-05   NaN
#
#   DAPR_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  SNOW  \
# 0             NaN   NaN             NaN   0.0        ,,7,1600   NaN
# 1             NaN   NaN             NaN   0.0        ,,7,1600   NaN
# 2             NaN   NaN             NaN   0.0        ,,7,1600   NaN
# 3             NaN   NaN             NaN   0.0        ,,7,1600   NaN
# 4             NaN   NaN             NaN   0.0        ,,7,1600   NaN
#
#   SNOW_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 0             NaN  80.0             ,,7  48.0             ,,7   NaN
# ...

# %%
sono_df.count()
# Out:
# STATION            3631
# LATITUDE           3631
# LONGITUDE          3631
# ELEVATION          3631
# DATE               3631
# DAPR                 22
# DAPR_ATTRIBUTES      22
# MDPR                 22
# MDPR_ATTRIBUTES      22
# PRCP               3609
# PRCP_ATTRIBUTES    3609
# SNOW               1160
# SNOW_ATTRIBUTES    1160
# TMAX               1437
# TMAX_ATTRIBUTES    1437
# TMIN               1434
# TMIN_ATTRIBUTES    1434
# TOBS                  0
# TOBS_ATTRIBUTES       0
# dtype: int64

# %%
sono_lite = sono_df.drop(columns=['DAPR_ATTRIBUTES','MDPR_ATTRIBUTES','PRCP_ATTRIBUTES','SNOW_ATTRIBUTES','TMAX_ATTRIBUTES','TMIN_ATTRIBUTES','TOBS','TOBS_ATTRIBUTES'])

# %%
sono_lite.head()
# Out:
#        STATION  LATITUDE  LONGITUDE  ELEVATION        DATE  DAPR  MDPR  PRCP  \
# 0  USC00048351   38.2994  -122.4622       29.6  2013-08-01   NaN   NaN   0.0
# 1  USC00048351   38.2994  -122.4622       29.6  2013-08-02   NaN   NaN   0.0
# 2  USC00048351   38.2994  -122.4622       29.6  2013-08-03   NaN   NaN   0.0
# 3  USC00048351   38.2994  -122.4622       29.6  2013-08-04   NaN   NaN   0.0
# 4  USC00048351   38.2994  -122.4622       29.6  2013-08-05   NaN   NaN   0.0
#
#    SNOW  TMAX  TMIN
# 0   NaN  80.0  48.0
# 1   NaN  82.0  48.0
# 2   NaN  78.0  48.0
# 3   NaN  75.0  51.0
# 4   NaN  80.0  51.0

# %%
sono_lite.count()
# Out:
# STATION      3631
# LATITUDE     3631
# LONGITUDE    3631
# ELEVATION    3631
# DATE         3631
# DAPR           22
# MDPR           22
# PRCP         3609
# SNOW         1160
# TMAX         1437
# TMIN         1434
# dtype: int64

# %%
al_countyfile = 'US_AL_cseat13t19.csv'
county_df = pd.read_csv(al_countyfile)
county_df.head()
# Out:
#        STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00012209  DECATUR 4 SE, AL US  34.57556  -86.93389      167.6
# 1  USC00012209  DECATUR 4 SE, AL US  34.57556  -86.93389      167.6
# 2  USC00012209  DECATUR 4 SE, AL US  34.57556  -86.93389      167.6
# 3  USC00012209  DECATUR 4 SE, AL US  34.57556  -86.93389      167.6
# 4  USC00012209  DECATUR 4 SE, AL US  34.57556  -86.93389      167.6
#
#          DATE  AWND  PRCP  SN32  SNOW  SX32  TAVG  TMAX  TMIN
# 0  2013-01-01   NaN  1.73   NaN   NaN   NaN   NaN  51.0  33.0
# 1  2013-01-02   NaN  0.00   NaN   NaN   NaN   NaN  51.0  33.0
# 2  2013-01-03   NaN  0.00   NaN   NaN   NaN   NaN  51.0  31.0
# 3  2013-01-04   NaN  0.00   NaN   NaN   NaN   NaN  45.0  28.0
# 4  2013-01-05   NaN  0.00   NaN   NaN   NaN   NaN  45.0  28.0

# %%
county_simpledf = county_df.drop(columns=['STATION','ELEVATION'])
county_simpledf.head()
# Out:
#                   NAME  LATITUDE  LONGITUDE        DATE  AWND  PRCP  SN32  \
# 0  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-01   NaN  1.73   NaN
# 1  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-02   NaN  0.00   NaN
# 2  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-03   NaN  0.00   NaN
# 3  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-04   NaN  0.00   NaN
# 4  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-05   NaN  0.00   NaN
#
#    SNOW  SX32  TAVG  TMAX  TMIN
# 0   NaN   NaN   NaN  51.0  33.0
# 1   NaN   NaN   NaN  51.0  33.0
# 2   NaN   NaN   NaN  51.0  31.0
# 3   NaN   NaN   NaN  45.0  28.0
# 4   NaN   NaN   NaN  45.0  28.0

# %%
county_simpledf.count()
# Out:
# NAME         116849
# LATITUDE     116849
# LONGITUDE    116849
# DATE         116849
# AWND          23543
# PRCP         110454
# SN32           6052
# SNOW          30072
# SX32           6053
# TAVG           9551
# TMAX          82344
# TMIN          82218
# dtype: int64

# %%
county_simpledf['NAME'].unique()
# Out:
# array(['DECATUR 4 SE, AL US', 'TROY MUNICIPAL AIRPORT, AL US',
#        'MOBILE DOWNTOWN AIRPORT, AL US', 'LAFAYETTE 2 W, AL US',
#        'BAY MINETTE, AL US', 'HEFLIN, AL US', 'JASPER, AL US',
#        'DADEVILLE 2, AL US', 'FAYETTE, AL US', 'ROCKFORD 3 ESE, AL US',
#        'MARION JUNCTION 2 NE, AL US', 'ATHENS, AL US',
#        'BREWTON 3 ENE, AL US', 'OPELIKA, AL US', 'MOULTON 2, AL US',
#        'PHENIX CITY 2.2 NNW, AL US', 'EVERGREEN MIDDLETON FIELD, AL US',
#        'FLORENCE 0.6 NE, AL US', 'HAMILTON 3 S, AL US',
#        'ENTERPRISE 2 W, AL US', 'RUSSELLVILLE NUMBER 2, AL US',
#        'CAMDEN 1.0 NNE, AL US', 'ONEONTA, AL US', 'FORT PAYNE, AL US',
#        'GENEVA NUMBER 2, AL US', 'SELMA, AL US',
#        'DOUBLE SPRINGS 3.2 NNE, AL US',
#        'GREENVILLE MAC CRENSHAW MEMORIAL AIRPORT, AL US',
#        'GUNTERSVILLE 2.2 SW, AL US', 'TALLADEGA ALABAMA, AL US',
#        'MONTGOMERY AIRPORT, AL US', 'FORT PAYNE 1.4 WSW, AL US',
# ...

# %%
decatur_df = county_simpledf.loc[county_simpledf['NAME'] == 'DECATUR 4 SE, AL US']
decatur_df.head()
# Out:
#                   NAME  LATITUDE  LONGITUDE        DATE  AWND  PRCP  SN32  \
# 0  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-01   NaN  1.73   NaN
# 1  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-02   NaN  0.00   NaN
# 2  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-03   NaN  0.00   NaN
# 3  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-04   NaN  0.00   NaN
# 4  DECATUR 4 SE, AL US  34.57556  -86.93389  2013-01-05   NaN  0.00   NaN
#
#    SNOW  SX32  TAVG  TMAX  TMIN
# 0   NaN   NaN   NaN  51.0  33.0
# 1   NaN   NaN   NaN  51.0  33.0
# 2   NaN   NaN   NaN  51.0  31.0
# 3   NaN   NaN   NaN  45.0  28.0
# 4   NaN   NaN   NaN  45.0  28.0

# %%
decatur_df['TMAX'].describe()
# Out:
# count    2333.000000
# mean       72.076297
# std        16.297097
# min        17.000000
# 25%        61.000000
# 50%        75.000000
# 75%        86.000000
# max        98.000000
# Name: TMAX, dtype: float64

# %%
decatur_tmax = list(decatur_df['TMAX'].describe())
decatur_tmin = list(decatur_df['TMIN'].describe())

# %%
decatur_tmax[1]
# Out:
# 72.07629661380197

# %%
decatur_tmin[1]
# Out:
# 51.564502164502166
